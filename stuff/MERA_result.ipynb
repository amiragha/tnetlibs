# %%
energy = array([-1.4062, -1.55886, -1.70861, -1.85415, -1.98159, -2.08274, -2.15963, -2.21713, -2.25955, -2.29256, -2.32183])+1.4142
exact = -4/pi
plot(energy,'ro')
hlines(exact,0,10)
xlabel("iteration number")
ylabel("Energy")
title("first try for minimizing the energy")
